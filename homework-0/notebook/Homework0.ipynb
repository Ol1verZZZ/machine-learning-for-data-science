# %% [markdown]
# <center><h1>DSCI-552 Homework 0</h1></center>
# <br>
# <center><font size="4">Name: Wenhao Zhang</font></center>
# <center><font size="4">Student ID: 7036767117</font></center>

# %% [markdown]
# ### 1. Setting up an Integrated Development Environment (IDE)

# %% [markdown]
# ![anaconda.png](attachment:d6607f44-895f-4e3a-9aa3-d9b2d98c672e.png)

# %% [markdown]
# Done it!

# %% [markdown]
# ### 2. Google Colab

# %% [markdown]
# Done it!

# %% [markdown]
# ### 3. Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### (a)

# %% [markdown]
# Good file!

# %% [markdown]
# #### (b)

# %%
pd.read_csv('../data/salaries_data/Salaries.csv')
# Out:
#        yearID teamID lgID   playerID    salary
# 0        1985    ATL   NL  barkele01    870000
# 1        1985    ATL   NL  bedrost01    550000
# 2        1985    ATL   NL  benedbr01    545000
# 3        1985    ATL   NL   campri01    633333
# 4        1985    ATL   NL  ceronri01    625000
# ...       ...    ...  ...        ...       ...
# 25570    2015    WAS   NL  treinbl01    512800
# 25571    2015    WAS   NL  ugglada01    507500
# 25572    2015    WAS   NL  werthja01  21000000
# 25573    2015    WAS   NL  zimmejo02  16500000
# 25574    2015    WAS   NL  zimmery01  14000000
#
# [25575 rows x 5 columns]

# %% [markdown]
# #### (c)

# %%
pd.read_csv('../data/salaries_data/Salaries.csv', index_col='playerID')
# Out:
#            yearID teamID lgID    salary
# playerID
# barkele01    1985    ATL   NL    870000
# bedrost01    1985    ATL   NL    550000
# benedbr01    1985    ATL   NL    545000
# campri01     1985    ATL   NL    633333
# ceronri01    1985    ATL   NL    625000
# ...           ...    ...  ...       ...
# treinbl01    2015    WAS   NL    512800
# ugglada01    2015    WAS   NL    507500
# werthja01    2015    WAS   NL  21000000
# zimmejo02    2015    WAS   NL  16500000
# zimmery01    2015    WAS   NL  14000000
#
# [25575 rows x 4 columns]

# %%
pd.read_csv('../data/salaries_data/Salaries.csv', header=1)
# Out:
#        1985  ATL  NL  barkele01    870000
# 0      1985  ATL  NL  bedrost01    550000
# 1      1985  ATL  NL  benedbr01    545000
# 2      1985  ATL  NL   campri01    633333
# 3      1985  ATL  NL  ceronri01    625000
# 4      1985  ATL  NL  chambch01    800000
# ...     ...  ...  ..        ...       ...
# 25569  2015  WAS  NL  treinbl01    512800
# 25570  2015  WAS  NL  ugglada01    507500
# 25571  2015  WAS  NL  werthja01  21000000
# 25572  2015  WAS  NL  zimmejo02  16500000
# 25573  2015  WAS  NL  zimmery01  14000000
#
# [25574 rows x 5 columns]

# %%
pd.read_csv('../data/salaries_data/Salaries.csv', skiprows=[2], header=None)
# Out:
#             0       1     2          3         4
# 0      yearID  teamID  lgID   playerID    salary
# 1        1985     ATL    NL  barkele01    870000
# 2        1985     ATL    NL  benedbr01    545000
# 3        1985     ATL    NL   campri01    633333
# 4        1985     ATL    NL  ceronri01    625000
# ...       ...     ...   ...        ...       ...
# 25570    2015     WAS    NL  treinbl01    512800
# 25571    2015     WAS    NL  ugglada01    507500
# 25572    2015     WAS    NL  werthja01  21000000
# 25573    2015     WAS    NL  zimmejo02  16500000
# 25574    2015     WAS    NL  zimmery01  14000000
#
# [25575 rows x 5 columns]

# %% [markdown]
# #### (d)

# %%
data = pd.read_csv('../data/salaries_data/Salaries.csv', index_col='playerID')
greater_than_1_mil = data[((data.teamID=='ATL') | (data.teamID=='HOU')) & (data.salary>=1000000)]
print('Number of players with ALT or HOU having salary greater than 1 million : ', greater_than_1_mil.shape[0])
print(greater_than_1_mil)
# Out:
# Number of players with ALT or HOU having salary greater than 1 million :  625
#            yearID teamID lgID   salary
# playerID
# hornebo01    1985    ATL   NL  1500000
# murphda05    1985    ATL   NL  1625000
# suttebr01    1985    ATL   NL  1354167
# ryanno01     1985    HOU   NL  1350000
# hornebo01    1986    ATL   NL  1800000
# ...           ...    ...  ...      ...
# rasmuco01    2015    HOU   AL  8000000
# singljo02    2015    HOU   AL  2000000
# sippto01     2015    HOU   AL  2400000
# thatcjo01    2015    HOU   AL  1000000
# valbulu01    2015    HOU   AL  4200000
#
# [625 rows x 4 columns]

# %% [markdown]
# #### (e)

# %%
data = pd.read_csv('../data/salaries_data/Salaries.csv', index_col='playerID')
data_ATL = data[(data.teamID=='ATL')]
data_ATL_std = data_ATL.std(axis=0)
print('Standard Deviation of team ATL salary is : ', data_ATL_std.salary)
data_ATL_mean = data_ATL.mean(axis=0)
print('Mean of team ATL salary is : ', data_ATL_mean.salary)
data_ATL_max = data_ATL.max(axis=0)
print('Max of team ATL salary is : ', data_ATL_max.salary)
data_ATL_quartile = data_ATL.quantile([0.25, 0.5, 0.75])
print('First Quartile, Median, Third Quartile of team ATL salary is :', data_ATL_quartile.salary)
data.describe()
# Out:
# Standard Deviation of team ATL salary is :  3432672.9832373876
# Mean of team ATL salary is :  2206239.316027088
# Max of team ATL salary is :  16061802
# First Quartile, Median, Third Quartile of team ATL salary is : 0.25     300000.0
# 0.50     600000.0
# 0.75    2390625.0
# Name: salary, dtype: float64
#              yearID        salary
# count  25575.000000  2.557500e+04
# mean    2000.374389  2.008563e+06
# std        8.610604  3.315706e+06
# min     1985.000000  0.000000e+00
# 25%     1993.000000  2.750000e+05
# 50%     2000.000000  5.500000e+05
# 75%     2008.000000  2.250000e+06
# max     2015.000000  3.300000e+07

# %% [markdown]
# #### (f)

# %%
# # 1st way, IOPub data rate exceeded
# data = pd.read_csv('../data/salaries_data/Salaries.csv') # no index setting
# df = pd.DataFrame(data)
# case_list = []
# for index, row in df.iterrows():
#     my_dict = {index : row}
#     case_list.append(my_dict)
# print(case_list)

# # 2nd way
data = pd.read_csv('../data/salaries_data/Salaries.csv')
result = data.to_dict(orient='records')
# print(result)

# %% [markdown]
# #### (g)

# %%
df = pd.DataFrame(result)
df.columns = ['a', 'b', 'c', 'd', 'e']
df
# Out:
#           a    b   c          d         e
# 0      1985  ATL  NL  barkele01    870000
# 1      1985  ATL  NL  bedrost01    550000
# 2      1985  ATL  NL  benedbr01    545000
# 3      1985  ATL  NL   campri01    633333
# 4      1985  ATL  NL  ceronri01    625000
# ...     ...  ...  ..        ...       ...
# 25570  2015  WAS  NL  treinbl01    512800
# 25571  2015  WAS  NL  ugglada01    507500
# 25572  2015  WAS  NL  werthja01  21000000
# 25573  2015  WAS  NL  zimmejo02  16500000
# 25574  2015  WAS  NL  zimmery01  14000000
#
# [25575 rows x 5 columns]

# %% [markdown]
# ### 4. Numpy

# %% [markdown]
# #### (a)

# %%
arr = np.array([[1, 2], [3, 4]])

# %% [markdown]
# #### (b)

# %%
arr.ndim
# Out:
# 2

# %%
arr.shape
# Out:
# (2, 2)

# %%
arr.size
# Out:
# 4

# %%
arr.dtype
# Out:
# dtype('int64')

# %%
arr.itemsize
# Out:
# 8

# %%
arr.data

# %% [markdown]
# #### (c)

# %%
arr = np.array([[1, 2], [3, 4]])
arr.flatten()
# Out:
# array([1, 2, 3, 4])

# %% [markdown]
# #### (d)

# %%
arr = np.array([[1, 2, 3], [3, 4, 6], [7, 8, 9]])
print(arr[1:])
arr[1:, 0:2]
# Out:
# [[3 4 6]
#  [7 8 9]]
# array([[3, 4],
#        [7, 8]])

# %% [markdown]
# #### (e)

# %%
np.argmin(arr)
# Out:
# 0

# %%
np.argmax(arr)
# Out:
# 8

# %%
np.min(arr)
# Out:
# 1

# %%
np.max(arr)
# Out:
# 9

# %%
np.mean(arr)
# Out:
# 4.777777777777778

# %%
np.sum(arr)
# Out:
# 43

# %%
np.std(arr)
# Out:
# 2.657391276244755

# %%
# np.dot(arr)
np.square(arr)
# Out:
# array([[ 1,  4,  9],
#        [ 9, 16, 36],
#        [49, 64, 81]])

# %%
np.sqrt(arr)
# Out:
# array([[1.        , 1.41421356, 1.73205081],
#        [1.73205081, 2.        , 2.44948974],
#        [2.64575131, 2.82842712, 3.        ]])

# %%
np.abs(arr)
# Out:
# array([[1, 2, 3],
#        [3, 4, 6],
#        [7, 8, 9]])

# %%
np.exp(arr)
# Out:
# array([[2.71828183e+00, 7.38905610e+00, 2.00855369e+01],
#        [2.00855369e+01, 5.45981500e+01, 4.03428793e+02],
#        [1.09663316e+03, 2.98095799e+03, 8.10308393e+03]])

# %%
np.sign(arr)
# Out:
# array([[1, 1, 1],
#        [1, 1, 1],
#        [1, 1, 1]])

# %%
# np.mod(arr)

# %% [markdown]
# #### (f)

# %%
# np.arrange()
# np.ones()
# np.zeros()
# np.linspace()
# np.concatenate()
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# ### 5. Scikit-Learn

# %% [markdown]
# Will learn it carefully!

# %% [markdown]
# ### 6. Git and GitHub

# %% [markdown]
# ### 7. Matplotlib

# %% [markdown]
# #### (a)

# %%
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, num=20)
y = np.array([j ** 2 for j in x])
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### (b)

# %%
x = np.linspace(-5, 5, num=20)
np.random.shuffle(x)
y = np.array([j ** 2 for j in x])
plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### (c)

# %%
x = np.linspace(-5, 5, num=20)
y1 = np.array([j for j in x])
y2 = np.array([j ** 2 for j in x])
y3 = np.array([j ** 3 for j in x])

plt.plot(x, y1)
plt.xlabel('x')
plt.ylabel('y1')
plt.show()

plt.plot(x, y2)
plt.xlabel('x')
plt.ylabel('y2')
plt.show()

plt.plot(x, y3)
plt.xlabel('x')
plt.ylabel('y3')
plt.show()

# %%
x = np.linspace(-5, 5, num=20)
y1 = np.array([j for j in x])
y2 = np.array([j ** 2 for j in x])
y3 = np.array([j ** 3 for j in x])
fig, (ax1, ax2, ax3) = plt.subplots(1,3)
ax1.plot(x, y1)
ax2.plot(x, y2)
ax3.plot(x, y3)
plt.show()

# %%
x = np.linspace(-5, 5, num=20)
y1 = np.array([j for j in x])
y2 = np.array([j ** 2 for j in x])
y3 = np.array([j ** 2 for j in x])

fig, (ax1, ax2, ax3) = plt.subplots(3, figsize=(9.5, 5.5))
fig.suptitle('Vertically stacked subplots')

csfont = {'fontname':'Comic Sans MS'}
hfont = {'fontname':'Helvetica'}

plt.title('Vertically stacked subplots',**csfont)
plt.xlabel('x', **hfont)

ax1.plot(x, y1)
ax2.plot(x, y2)
ax3.plot(x, y3)
plt.show()

# %% [markdown]
# #### (d)

# %% [markdown]
# Got it!

# %% [markdown]
# #### (e)

# %%
x = np.linspace(-5, 5, num=20)
y = np.array([j for j in x])

fig, ax = plt.subplots()

ax.plot(x, y)

# ax.set_xscale('log')
ax.set_yscale('log')

plt.xlabel('x')
plt.ylabel('logx')

plt.show()

# %% [markdown]
# ### 8. Seaborn

# %% [markdown]
# #### (a)

# %%
data = pd.read_csv('../data/salaries_data/Salaries.csv', index_col='playerID')

# %% [markdown]
# #### (b)

# %%
df = pd.DataFrame(data)
df_copy = df
cols_with_team_ATL = df_copy.loc[df_copy.teamID=='ATL', ]
cols_with_team_ATL.plot.scatter(x='salary', y='yearID', title='Scatterplot between yearID and salary')
# Out:
# <AxesSubplot:title={'center':'Scatterplot between yearID and salary'}, xlabel='salary', ylabel='yearID'>

# %%
cols_with_year_1985 = df_copy.loc[df_copy.yearID==1985, ]
cols_with_year_1985['salary'] = cols_with_year_1985['salary'].astype(int)

cols_with_year_1985.plot.bar(x="teamID", y="salary", rot=70, title="Average Salary for each team for the year 1985")
# Out:
# <ipython-input-83-8efe575793a1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cols_with_year_1985['salary'] = cols_with_year_1985['salary'].astype(int)
# <AxesSubplot:title={'center':'Average Salary for each team for the year 1985'}, xlabel='teamID'>

# %%
cols_with_team_ATL['salary'] = cols_with_team_ATL['salary'].astype(int)
cols_with_team_ATL['yearID'] = cols_with_team_ATL['yearID'].astype(int)

cols_with_team_ATL.plot.line(x = 'yearID', y = 'salary', title="Average Salary change by year for the team = ATL")
# Out:
# <ipython-input-84-5928480531de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cols_with_team_ATL['salary'] = cols_with_team_ATL['salary'].astype(int)
# <ipython-input-84-5928480531de>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cols_with_team_ATL['yearID'] = cols_with_team_ATL['yearID'].astype(int)
# <AxesSubplot:title={'center':'Average Salary change by year for the team = ATL'}, xlabel='yearID'>

# %% [markdown]
# #### (c)

# %% [markdown]
# #### (d)

# %%
cols_with_year_1985 = df_copy.loc[df_copy.yearID=="1985", ]
cols_with_year_1985['salary'] = cols_with_year_1985['salary'].astype(int)

fig, ax = plt.subplots(figsize=(7,5))
sns.boxplot(x='teamID', y='salary', data=cols_with_year_1985, orient='v')
fig.subplots_adjust(top=0.9)
ax.text(x=0.5, y=1.1, s="Boxplot of salary distribution for the year 1985 for each team", fontsize=16, weight='bold', ha='center', va='bottom', transform=ax.transAxes)
# Out:
# <ipython-input-87-fc9d9abafb6e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cols_with_year_1985['salary'] = cols_with_year_1985['salary'].astype(int)
# Text(0.5, 1.1, 'Boxplot of salary distribution for the year 1985 for each team')

# %% [markdown]
# #### (e)

# %%
import seaborn as sns

var_set = [
    "yearID",
    "teamID",
    "lgID",
    "playerID",
    "salary"
]

head_set = []
head_set.extend(var_set)
head_set.append("num_feat")

df = pd.read_csv('../data/salaries_data/Salaries.csv',index_col='playerID', header=None, names=head_set)

df['num_feat'] = 100 * np.random.random_sample(df.shape[0])

df_copy = df
cols_with_team_ATL = df_copy.loc[df_copy.teamID=="ATL", ]

# Create the default pairplot
pairplot_fig = sns.pairplot(cols_with_team_ATL, vars=['yearID', 'salary', 'num_feat'])
plt.subplots_adjust(top=0.9)
pairplot_fig.fig.suptitle("Scatter plots among all numeric features in the data frame for teamID = ATL", fontsize=18, alpha=0.9, weight='bold')
plt.show()
